# %%
import pandas as pd
import matplotlib as plt
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from  db_conn import url
import psycopg2

# %%
postgresInfo = f'postgresql://{url}'

# %%
conn_string = postgresInfo

db = create_engine(conn_string)
conn = db.connect()

conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()

df = pd.read_sql_query('''SELECT * FROM players_of_interest ;''', db)

df
# Out:
#      season                name team position  games_played  corsi_percentage  \
# 0      2012         Jack Hillen  WSH        D            23              0.49
# 1      2012        David Perron  STL        L            48              0.58
# 2      2012         Ryane Clowe  NYR        L            40              0.58
# 3      2012   Nicklas Grossmann  PHI        D            30              0.41
# 4      2012  Vladimir Tarasenko  STL        R            38              0.63
# ..      ...                 ...  ...      ...           ...               ...
# 574    2022          Sam Gagner  WPG        C            48              0.57
# 575    2022     Mark Borowiecki  NSH        D             4              0.44
# 576    2022        Sonny Milano  WSH        L            64              0.52
# 577    2022    Nikita Soshnikov  NYI        R             3              0.59
# 578    2022  Vladimir Tarasenko  NYR        R            69              0.52
#
#      fenwick_percentage  goals  points  penalty_minutes  hits  takeaways  \
# 0                  0.50      3       9               14    10          2
# 1                  0.58     10      25               44    48         26
# 2                  0.58      3      19               53    99         13
# 3                  0.42      1       4               21    81          6
# 4                  0.63      8      19               10    28         14
# ..                  ...    ...     ...              ...   ...        ...
# 574                0.56      8      14               13    16         12
# 575                0.39      0       0               12     5          0
# 576                0.51     11      33               18    39         21
# 577                0.59      0       0                0     8          0
# 578                0.52     18      50                8    75         24
#
#      giveaways  games_missed  points_per_game
# 0           13             0             0.39
# 1           14             0             0.52
# 2           26             0             0.48
# 3           17            18             0.13
# 4            6            10             0.50
# ..         ...           ...              ...
# 574         10             0             0.29
# 575          0             0             0.00
# 576         21             0             0.52
# 577          1             0             0.00
# 578         26             0             0.72
#
# [579 rows x 15 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      season                name team position  games_played  corsi_percentage  \
# 0      2012         Jack Hillen  WSH        D            23              0.49
# 1      2012        David Perron  STL        L            48              0.58
# 2      2012         Ryane Clowe  NYR        L            40              0.58
# 3      2012   Nicklas Grossmann  PHI        D            30              0.41
# 4      2012  Vladimir Tarasenko  STL        R            38              0.63
# ..      ...                 ...  ...      ...           ...               ...
# 574    2022          Sam Gagner  WPG        C            48              0.57
# 575    2022     Mark Borowiecki  NSH        D             4              0.44
# 576    2022        Sonny Milano  WSH        L            64              0.52
# 577    2022    Nikita Soshnikov  NYI        R             3              0.59
# 578    2022  Vladimir Tarasenko  NYR        R            69              0.52
#
#      fenwick_percentage  goals  points  penalty_minutes  hits  takeaways  \
# 0                  0.50      3       9               14    10          2
# 1                  0.58     10      25               44    48         26
# 2                  0.58      3      19               53    99         13
# 3                  0.42      1       4               21    81          6
# 4                  0.63      8      19               10    28         14
# ..                  ...    ...     ...              ...   ...        ...
# 574                0.56      8      14               13    16         12
# 575                0.39      0       0               12     5          0
# 576                0.51     11      33               18    39         21
# 577                0.59      0       0                0     8          0
# 578                0.52     18      50                8    75         24
#
#      giveaways  games_missed  points_per_game
# 0           13             0             0.39
# 1           14             0             0.52
# 2           26             0             0.48
# 3           17            18             0.13
# 4            6            10             0.50
# ..         ...           ...              ...
# 574         10             0             0.29
# 575          0             0             0.00
# 576         21             0             0.52
# 577          1             0             0.00
# 578         26             0             0.72
#
# [579 rows x 15 columns]>

# %%
print(df.isnull().any())
# Out:
# season                False
# name                  False
# team                  False
# position              False
# games_played          False
# corsi_percentage      False
# fenwick_percentage    False
# goals                 False
# points                False
# penalty_minutes       False
# hits                  False
# takeaways             False
# giveaways             False
# games_missed          False
# points_per_game       False
# dtype: bool

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'season'}>,
#         <AxesSubplot:title={'center':'games_played'}>,
#         <AxesSubplot:title={'center':'corsi_percentage'}>],
#        [<AxesSubplot:title={'center':'fenwick_percentage'}>,
#         <AxesSubplot:title={'center':'goals'}>,
#         <AxesSubplot:title={'center':'points'}>],
#        [<AxesSubplot:title={'center':'penalty_minutes'}>,
#         <AxesSubplot:title={'center':'hits'}>,
#         <AxesSubplot:title={'center':'takeaways'}>],
#        [<AxesSubplot:title={'center':'giveaways'}>,
#         <AxesSubplot:title={'center':'games_missed'}>,
#         <AxesSubplot:title={'center':'points_per_game'}>]], dtype=object)

# %%
df['games_missed'].hist()
# Out:
# <AxesSubplot:>

# %%
df['points_per_game'].hist()
# Out:
# <AxesSubplot:>

# %%
df['corsi_percentage'].hist()
# Out:
# <AxesSubplot:>

# %%
df['fenwick_percentage'].hist()
# Out:
# <AxesSubplot:>

# %%
games_missed = df['games_missed'].value_counts()
print(games_missed)
# Out:
# 0     483
# 10     16
# 12      9
# 11      7
# 14      6
# 15      6
# 18      5
# 16      4
# 21      4
# 25      3
# 20      3
# 17      3
# 19      3
# 42      2
# 27      2
# 78      2
# 13      2
# 34      2
# 24      2
# 44      1
# 22      1
# 26      1
# 62      1
# 40      1
# 69      1
# 35      1
# 74      1
# 81      1
# 80      1
# 56      1
# 23      1
# 46      1
# 41      1
# 50      1
# Name: games_missed, dtype: int64

# %%
df['missed_games_last_season'] = (df['games_missed'].shift(1) > 10).astype(int)
previous_season_missed = df[df['missed_games_last_season'] == 1]
previous_season_not_missed = df[df['missed_games_last_season'] == 0]
previous_season_missed_mean = previous_season_missed.mean()
previous_season_not_missed_mean = previous_season_not_missed.mean()
# Out:
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   after removing the cwd from sys.path.
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """

# %%
difference = previous_season_missed_mean - previous_season_not_missed_mean
print(difference)
# Out:
# season                      0.067034
# games_played                2.087575
# corsi_percentage            0.008212
# fenwick_percentage          0.011514
# goals                       2.012375
# points                      5.093763
# penalty_minutes            -0.619564
# hits                       -0.792911
# takeaways                   1.600476
# giveaways                   0.967735
# games_missed                0.146493
# points_per_game             0.059521
# missed_games_last_season    1.000000
# dtype: float64

# %%
# Filter dataframe to include only players who missed 10 or more games in the previous season
prev_season = df[df["games_missed"].shift(1) >= 10]

# Print unique values of "name" column in filtered dataframe
print(prev_season["name"].unique())
# Out:
# ['Vladimir Tarasenko' 'Trevor Lewis' 'Jordan Staal' 'John Moore'
#  'Peter Holland' 'Simon Despres' 'David Perron' 'Andrew Shaw'
#  'Tyler Bozak' 'Jack Hillen' 'Marcus Johansson' 'Ales Hemsky' 'Saku Koivu'
#  'Travis Hamonic' 'George Parros' 'Jakub Voracek' 'Justin Falk'
#  'Carl Gunnarsson' 'Lubomir Visnovsky' 'Jonathan Huberdeau'
#  'Phillip Danault' 'Marc Staal' 'Keith Ballard' 'Raphael Diaz'
#  'Loui Eriksson' 'Korbinian Holzer' 'Ryane Clowe' 'Leo Komarov'
#  'Sonny Milano' 'Connor Murphy' 'Micheal Ferland' 'Radko Gudas'
#  'Sami Vatanen' 'Patrick Sharp' 'David Warsofsky' 'Jonathan Toews'
#  'Roman Josi' 'Ondrej Kase' 'Scott Laughton' 'Brandon Pirri'
#  'Mathieu Perreault' 'Nikita Soshnikov' 'Teuvo Teravainen' 'Sam Gagner'
#  'Matt Hunwick' 'Charlie McAvoy' 'Patric Hornqvist' 'J.T. Compher'
#  'Jake Muzzin' 'Scott Sabourin' 'Trevor Moore' 'Alec Martinez']

# %%
filtered_df = df[df['games_missed'] >= 10]

filtered_df.head()
# Out:
#     season                name team position  games_played  corsi_percentage  \
# 3     2012   Nicklas Grossmann  PHI        D            30              0.41
# 4     2012  Vladimir Tarasenko  STL        R            38              0.63
# 9     2012        Eric Selleck  FLA        L             2              0.44
# 20    2012         Chad LaRose  CAR        R            35              0.54
# 31    2012        Rene Bourque  MTL        R            27              0.55
#
#     fenwick_percentage  goals  points  penalty_minutes  hits  takeaways  \
# 3                 0.42      1       4               21    81          6
# 4                 0.63      8      19               10    28         14
# 9                 0.48      0       1                7     5          2
# 20                0.54      2       4               19    59          8
# 31                0.55      7      13               22    37          8
#
#     giveaways  games_missed  points_per_game  missed_games_last_season
# 3          17            18             0.13                         0
# 4           6            10             0.50                         1
# 9           0            16             0.50                         0
# 20          6            10             0.11                         0
# 31          6            21             0.48                         0

# %%
new_df = df.loc[df['games_missed'] >= 5, ['season', 'name', 'games_played', 'corsi_percentage', 'fenwick_percentage', 'games_missed', 'points_per_game']]
new_df.head(20)
# Out:
#      season                name  games_played  corsi_percentage  \
# 3      2012   Nicklas Grossmann            30              0.41
# 4      2012  Vladimir Tarasenko            38              0.63
# 9      2012        Eric Selleck             2              0.44
# 20     2012         Chad LaRose            35              0.54
# 31     2012        Rene Bourque            27              0.55
# 56     2012        Raphael Diaz            23              0.51
# 60     2012       Daniel Briere            34              0.54
# 65     2013          Roman Josi            72              0.49
# 68     2013  Jonathan Huberdeau            69              0.56
# 76     2013       Tomas Kopecky            49              0.49
# 79     2013     Alexander Semin            65              0.60
# 82     2013   Michael Bournival            60              0.43
# 85     2013       Loui Eriksson            61              0.59
# 86     2013          Saku Koivu            65              0.43
# 87     2013      Travis Hamonic            69              0.47
# 91     2013          Marc Staal            72              0.51
# 102    2013       Daniel Briere            69              0.52
# 103    2013       George Parros            22              0.28
# 104    2013       George Parros            22              0.28
# 115    2013         Tim Gleason            56              0.39
#
#      fenwick_percentage  games_missed  points_per_game
# 3                  0.42            18             0.13
# 4                  0.63            10             0.50
# 9                  0.48            16             0.50
# 20                 0.54            10             0.11
# 31                 0.55            21             0.48
# 56                 0.54            25             0.61
# 60                 0.52            10             0.47
# 65                 0.51            10             0.56
# 68                 0.54            11             0.41
# 76                 0.49            24             0.24
# 79                 0.59            12             0.65
# 82                 0.45            14             0.23
# 85                 0.58            15             0.61
# 86                 0.43            15             0.45
# 87                 0.47            12             0.26
# 91                 0.50            10             0.19
# 102                0.52            10             0.36
# 103                0.27            10             0.05
# 104                0.27            12             0.05
# 115                0.38            10             0.11

# %%
new_df.describe
# Out:
# <bound method NDFrame.describe of      season                name  games_played  corsi_percentage  \
# 3      2012   Nicklas Grossmann            30              0.41
# 4      2012  Vladimir Tarasenko            38              0.63
# 9      2012        Eric Selleck             2              0.44
# 20     2012         Chad LaRose            35              0.54
# 31     2012        Rene Bourque            27              0.55
# ..      ...                 ...           ...               ...
# 549    2022         Radko Gudas            72              0.49
# 554    2022    Patric Hornqvist            22              0.63
# 557    2022      Travis Dermott            11              0.40
# 562    2022         Ondrej Kase             1              0.74
# 569    2022       Jakub Voracek            11              0.50
#
#      fenwick_percentage  games_missed  points_per_game
# 3                  0.42            18             0.13
# 4                  0.63            10             0.50
# 9                  0.48            16             0.50
# 20                 0.54            10             0.11
# 31                 0.55            21             0.48
# ..                  ...           ...              ...
# 549                0.49            10             0.24
# 554                0.62            40             0.14
# 557                0.40            34             0.09
# 562                0.72            62             0.00
# 569                0.50            50             0.55
#
# [96 rows x 7 columns]>

# %%
# Create a new column for the next season
new_df['next_season'] = new_df['season'] + 1

# Merge the original dataframe with itself based on the name and the next season
merged_df = pd.merge(new_df, new_df[['name', 'season', 'points_per_game']], left_on=['name', 'next_season'], right_on=['name', 'season'], suffixes=('', '_next'))

# Select the desired columns
result_df = merged_df[['season', 'name', 'games_played', 'corsi_percentage', 'fenwick_percentage', 'games_missed', 'points_per_game', 'points_per_game_next']]

# %%
result_df.head(20)
# Out:
#    season              name  games_played  corsi_percentage  \
# 0    2012     Daniel Briere            34              0.54
# 1    2014  Clarke MacArthur            62              0.57
# 2    2014     Johan Franzen            33              0.61
# 3    2015  Clarke MacArthur             4              0.58
# 4    2017       Ondrej Kase            66              0.56
# 5    2018    Drake Caggiula            55              0.49
# 6    2019       Andrew Shaw            26              0.56
# 7    2021       Ondrej Kase            50              0.51
#
#    fenwick_percentage  games_missed  points_per_game  points_per_game_next
# 0                0.52            10             0.47                  0.36
# 1                0.54            18             0.58                  0.00
# 2                0.59            42             0.67                  0.50
# 3                0.57            78             0.00                  0.00
# 4                0.55            10             0.58                  0.67
# 5                0.48            13             0.42                  0.38
# 6                0.54            44             0.38                  0.29
# 7                0.50            20             0.54                  0.00

# %%
df1 = pd.read_csv("../Resources/Players_of_Interest.csv")
df1.head()
# Out:
#    season                name team position  games_played  corsi_percentage  \
# 0    2012         Jack Hillen  WSH        D            23              0.49
# 1    2012        David Perron  STL        L            48              0.58
# 2    2012         Ryane Clowe  NYR        L            40              0.58
# 3    2012   Nicklas Grossmann  PHI        D            30              0.41
# 4    2012  Vladimir Tarasenko  STL        R            38              0.63
#
#    fenwick_percentage  goals  points  penalty_minutes  hits  takeaways  \
# 0                0.50      3       9               14    10          2
# 1                0.58     10      25               44    48         26
# 2                0.58      3      19               53    99         13
# 3                0.42      1       4               21    81          6
# 4                0.63      8      19               10    28         14
#
#    giveaways  games_missed  points_per_game
# 0         13             0             0.39
# 1         14             0             0.52
# 2         26             0             0.48
# 3         17            18             0.13
# 4          6            10             0.50

# %%
#sort dataset by name and season
df1 = df1.sort_values(['name', 'season'])

#add columns for PPGP and PPGN
df1['PPGP'] = 0.0
df1['PPGN'] = 0.0

#loop through each player in dataset
for player in df1['name'].unique():
    #get indices of rows for this player
    player_indices = df1.index[df1['name'] == player]
    
    #loop through each row for this player
    for i in range(len(player_indices)):
        #get the index of the previous season row
        prev_index = player_indices[i] - 1
        
        #if previous season row exists and player missed more than 5 games in the current row
        if prev_index >= 0 and df1.loc[player_indices[i], 'games_missed'] > 5:
            #set PPGP to the points per game of the previous season row
            df1.loc[player_indices[i], 'PPGP'] = df1.loc[prev_index, 'points_per_game']
        
        #get index of the next season row
        next_index = player_indices[i] + 1
        
        #if next season row exists and the player missed more than 5 games in the current row
        if next_index < len(df1.index) and df1.loc[player_indices[i], 'games_missed'] > 5:
            #set PPGN to points per game of the next season row
            df1.loc[player_indices[i], 'PPGN'] = df1.loc[next_index, 'points_per_game']

# %%
df1.head(10)
# Out:
#      season           name team position  games_played  corsi_percentage  \
# 17     2012  Alec Martinez  L.A        D            27              0.60
# 101    2013  Alec Martinez  L.A        D            61              0.61
# 129    2014  Alec Martinez  L.A        D            56              0.53
# 188    2015  Alec Martinez  L.A        D            78              0.52
# 301    2016  Alec Martinez  L.A        D            82              0.54
# 308    2017  Alec Martinez  L.A        D            77              0.47
# 371    2018  Alec Martinez  L.A        D            60              0.47
# 451    2019  Alec Martinez  VGK        D            51              0.50
# 458    2020  Alec Martinez  VGK        D            53              0.49
# 541    2021  Alec Martinez  VGK        D            26              0.50
#
#      fenwick_percentage  goals  points  penalty_minutes  hits  takeaways  \
# 17                 0.59      1       5               10    31          2
# 101                0.61     11      22               14    96          5
# 129                0.53      6      22               10    95         11
# 188                0.52     10      31               40   164          8
# 301                0.55      9      39               24   137          5
# 308                0.47      9      25               34   100         11
# 371                0.47      4      18                8    78         12
# 451                0.51      3      17               23    43         14
# 458                0.51      9      31               12    44         12
# 541                0.51      3       8                4    26          8
#
#      giveaways  games_missed  points_per_game  PPGP  PPGN
# 17          13             0             0.19  0.00  0.00
# 101         27             0             0.36  0.00  0.00
# 129         38            18             0.39  0.16  0.46
# 188         60             0             0.40  0.00  0.00
# 301         51             0             0.48  0.00  0.00
# 308         81             0             0.32  0.00  0.00
# 371         70             0             0.30  0.00  0.00
# 451         32             0             0.33  0.00  0.00
# 458         26             0             0.58  0.00  0.00
# 541         19             0             0.31  0.00  0.00

# %%
df2 = pd.read_csv('../Resources/Players_of_Interest.csv')

new_df = pd.DataFrame(columns=['season', 'name', 'team', 'position', 'games_played', 'corsi_percentage', 'fenwick_percentage', 'goals', 'points', 'penalty_minutes', 'hits', 'takeaways', 'giveaways', 'games_missed', 'points_per_game', 'PPGP', 'PPGN'])

for i in range(len(df2)):
    #check if player missed more than 5 games in a season
    if df2.iloc[i]['games_missed'] > 5:
        name = df2.iloc[i]['name']
        season = df2.iloc[i]['season']
        #get previous season's points per game
        prev_ppg = df2.loc[(df2['name'] == name) & (df2['season'] == season-1), 'points_per_game'].values
        if len(prev_ppg) == 0:
            prev_ppg = None
        else:
            prev_ppg = prev_ppg[0]
        #get next season's points per game
        next_ppg = df2.loc[(df2['name'] == name) & (df2['season'] == season+1), 'points_per_game'].values
        if len(next_ppg) == 0:
            next_ppg = None
        else:
            next_ppg = next_ppg[0]
        #add new row to dataframe
        new_df = new_df.append({
            'season': df2.iloc[i]['season'],
            'name': df2.iloc[i]['name'],
            'team': df2.iloc[i]['team'],
            'position': df2.iloc[i]['position'],
            'games_played': df2.iloc[i]['games_played'],
            'corsi_percentage': df2.iloc[i]['corsi_percentage'],
            'fenwick_percentage': df2.iloc[i]['fenwick_percentage'],
            'goals': df2.iloc[i]['goals'],
            'points': df2.iloc[i]['points'],
            'penalty_minutes': df2.iloc[i]['penalty_minutes'],
            'hits': df2.iloc[i]['hits'],
            'takeaways': df2.iloc[i]['takeaways'],
            'giveaways': df2.iloc[i]['giveaways'],
            'games_missed': df2.iloc[i]['games_missed'],
            'points_per_game': df2.iloc[i]['points_per_game'],
            'PPGP': prev_ppg,
            'PPGN': next_ppg
        }, ignore_index=True)

# %%
new_df
# Out:
#    season                name team position games_played  corsi_percentage  \
# 0    2012   Nicklas Grossmann  PHI        D           30              0.41
# 1    2012  Vladimir Tarasenko  STL        R           38              0.63
# 2    2012        Eric Selleck  FLA        L            2              0.44
# 3    2012         Chad LaRose  CAR        R           35              0.54
# 4    2012        Rene Bourque  MTL        R           27              0.55
# ..    ...                 ...  ...      ...          ...               ...
# 91   2022         Radko Gudas  FLA        D           72              0.49
# 92   2022    Patric Hornqvist  FLA        R           22              0.63
# 93   2022      Travis Dermott  VAN        D           11              0.40
# 94   2022         Ondrej Kase  CAR        R            1              0.74
# 95   2022       Jakub Voracek  CBJ        R           11              0.50
#
#     fenwick_percentage goals points penalty_minutes hits takeaways giveaways  \
# 0                 0.42     1      4              21   81         6        17
# 1                 0.63     8     19              10   28        14         6
# 2                 0.48     0      1               7    5         2         0
# 3                 0.54     2      4              19   59         8         6
# 4                 0.55     7     13              22   37         8         6
# ..                 ...   ...    ...             ...  ...       ...       ...
# 91                0.49     2     17              79  312        20        36
# 92                0.62     1      3              13   18         5         0
# 93                0.40     1      1               2   10         1         1
# 94                0.72     0      0               0    1         1         0
# 95                0.50     1      6               0    2         4         1
#
#    games_missed  points_per_game  PPGP  PPGN
# 0            18             0.13   NaN  0.18
# 1            10             0.50   NaN  0.67
# 2            16             0.50   NaN  None
# 3            10             0.11   NaN  None
# 4            21             0.48   NaN  0.25
# ..          ...              ...   ...   ...
# 91           10             0.24  0.21  None
# 92           40             0.14  0.43  None
# 93           34             0.09  0.12  None
# 94           62             0.00  0.54  None
# 95           50             0.55  0.78  None
#
# [96 rows x 17 columns]

# %%
new_df = new_df.dropna(subset=['PPGP', 'PPGN'])
new_df
# Out:
#    season                name team position games_played  corsi_percentage  \
# 7    2013          Roman Josi  NSH        D           72              0.49
# 8    2013  Jonathan Huberdeau  FLA        L           69              0.56
# 9    2013       Tomas Kopecky  FLA        R           49              0.49
# 10   2013     Alexander Semin  CAR        R           65              0.60
# 12   2013       Loui Eriksson  BOS        L           61              0.59
# 14   2013      Travis Hamonic  NYI        D           69              0.47
# 15   2013          Marc Staal  NYR        D           72              0.51
# 16   2013       Daniel Briere  MTL        C           69              0.52
# 19   2013         Tim Gleason  TOR        D           56              0.39
# 21   2013   Lubomir Visnovsky  NYI        D           24              0.61
# 22   2013   Lubomir Visnovsky  NYI        D           24              0.61
# 24   2014       Alec Martinez  L.A        D           56              0.53
# 26   2014   Mikhail Grabovski  NYI        C           51              0.58
# 27   2014        Matt Calvert  CBJ        L           56              0.46
# 28   2014     Carl Gunnarsson  STL        D           61              0.48
# 31   2014    Clarke MacArthur  OTT        L           62              0.57
# 32   2014       Brandon Pirri  FLA        R           49              0.56
# 33   2014       Johan Franzen  DET        R           33              0.61
# 37   2015          Sam Gagner  PHI        C           53              0.55
# 39   2015   Mathieu Perreault  WPG        C           71              0.64
# 40   2015       Peter Holland  TOR        C           65              0.59
# 41   2015       Mark Barberio  MTL        D           30              0.54
# 42   2015           Ben Smith  TOR        R           22              0.42
# 43   2015    Clarke MacArthur  OTT        L            4              0.58
# 44   2015     David Warsofsky  N.J        D           22              0.58
# 45   2016          John Moore  N.J        D           63              0.45
# 49   2016       Patrick Sharp  DAL        L           48              0.56
# 50   2016       Patrick Sharp  DAL        L           48              0.56
# 52   2016         Andrew Shaw  MTL        R           68              0.58
# 53   2017     Phillip Danault  MTL        C           52              0.50
# 54   2017        Trevor Lewis  L.A        C           68              0.46
# 56   2017         Ondrej Kase  ANA        R           66              0.56
# 57   2017        Matt Hunwick  PIT        D           42              0.45
# 58   2017     Mark Borowiecki  OTT        D           52              0.44
# 59   2017    Marcus Johansson  N.J        L           29              0.54
# 60   2017    Marcus Johansson  N.J        L           29              0.54
# 63   2018          T.J. Oshie  WSH        R           69              0.57
# 64   2018        J.T. Compher  COL        L           66              0.50
# 65   2018        Sami Vatanen  N.J        D           50              0.49
# 66   2018        David Perron  STL        L           57              0.56
# 67   2018     Alexander Edler  VAN        D           56              0.49
# 69   2018      Charlie McAvoy  BOS        D           54              0.54
# 70   2018        Jordan Staal  CAR        C           50              0.59
# 71   2018         Ondrej Kase  ANA        R           30              0.60
# 72   2018      Drake Caggiula  CHI        C           55              0.49
# 73   2019      Drake Caggiula  CHI        C           40              0.48
# 74   2019         Kyle Okposo  BUF        R           52              0.52
# 76   2019        Trevor Moore  L.A        C           42              0.46
# 78   2019        Kris Russell  EDM        D           55              0.38
# 79   2019         Andrew Shaw  CHI        C           26              0.56
# 80   2020         Tyler Bozak  STL        C           31              0.40
# 81   2020        Sonny Milano  ANA        L            6              0.63
# 82   2020    Teuvo Teravainen  CAR        L           21              0.58
# 84   2020        Dylan Strome  CHI        C           40              0.53
# 85   2021       Connor Murphy  CHI        D           57              0.39
# 86   2021         Ondrej Kase  TOR        R           50              0.51
# 87   2021    Christian Dvorak  MTL        L           56              0.46
# 89   2021         Jake Muzzin  TOR        D           47              0.48
# 90   2021      Scott Laughton  PHI        C           67              0.45
#
#     fenwick_percentage goals points penalty_minutes hits takeaways giveaways  \
# 7                 0.51    13     40              18   32        22        34
# 8                 0.54     9     28              37   73        32        21
# 9                 0.49     4     12              18   31        17        10
# 10                0.59    22     42              42   22        49        56
# 12                0.58    10     37               6   12        31        17
# 14                0.47     3     18              48   93        40        51
# 15                0.50     3     14              24   83        41        48
# 16                0.52    13     25              30   23        22        17
# 19                0.38     1      6              55  156         9        26
# 21                0.59     3     11              10   14        15        18
# 22                0.59     3     11              10   14        15        18
# 24                0.53     6     22              10   95        11        38
# 26                0.59     9     19               8   11        26        31
# 27                0.45    13     23              28   92        26        19
# 28                0.50     2     12               2   42        11        13
# 31                0.54    16     36              36   70        31        36
# 32                0.56    22     24              14   39        18        12
# 33                0.59     7     22              30   45         4        17
# 37                0.54     8     16              15   17        20        13
# 39                0.63     9     41              36   83        31        26
# 40                0.59     9     27              28   78        34        21
# 41                0.54     2     10               6   12        11        19
# 42                0.42     2      6               0   18         8         3
# 43                0.57     0      0               0    3         0         0
# 44                0.58     1      2               2    5         4        17
# 45                0.43    12     22              29   68         7        41
# 49                0.57     8     18              31   24        16        21
# 50                0.57     8     18              31   24        16        21
# 52                0.57    12     29              80  147        28        29
# 53                0.50     8     25              34   59        38        20
# 54                0.47    14     26              25  125        19        14
# 56                0.55    20     38              14   28        29        31
# 57                0.44     4     10              21   51        14        20
# 58                0.47     3     11              64  226        11        17
# 59                0.54     5     14              14    8        15        21
# 60                0.54     5     14              14    8        15        21
# 63                0.57    25     54              36  133        46        38
# 64                0.50    16     33              31   33        23        23
# 65                0.49     4     17              22   68        16        36
# 66                0.56    23     46              46   52        41        17
# 67                0.51    10     31              54  127        13        38
# 69                0.55     7     28              45   90        30        54
# 70                0.58    11     29              24  121        39        24
# 71                0.59    11     20               2   17        15        18
# 72                0.48    12     23              28  135        18        22
# 73                0.47     9     15              32   81        19         5
# 74                0.52     9     19              18   55        15        13
# 76                0.45     6     10               6   60        21        19
# 78                0.40     0      9              14   71        31        37
# 79                0.54     3     10              33   74        12        15
# 80                0.40     5     17              10   17        12        10
# 81                0.66     0      0               0    4         0         3
# 82                0.57     5     14               4    8        10        12
# 84                0.53     9     17              14    8        17        16
# 85                0.39     4     10              47  130        19        47
# 86                0.50    14     27              14   29        28        16
# 87                0.45    11     33              14   32        16        32
# 89                0.48     3     14              16  105        12        44
# 90                0.45    11     30              35  151        31        40
#
#    games_missed  points_per_game  PPGP  PPGN
# 7            10             0.56  0.38  0.68
# 8            11             0.41  0.65  0.68
# 9            24             0.24  0.57  0.12
# 10           12             0.65   1.0  0.33
# 12           15             0.61   0.6  0.58
# 14           12             0.26  0.21  0.46
# 15           10             0.19  0.52  0.25
# 16           10             0.36  0.47  0.21
# 19           10             0.11  0.21  0.12
# 21           12             0.46   0.4  0.38
# 22           46             0.46   0.4  0.38
# 24           18             0.39  0.36   0.4
# 26           23             0.37   0.6  0.43
# 27           15             0.41  0.41  0.33
# 28           10             0.20  0.21  0.12
# 31           18             0.58   0.7   0.0
# 32           10             0.49  0.51  0.48
# 33           42             0.67  0.76   0.5
# 37           11             0.30  0.51  0.62
# 39           10             0.58  0.66  0.69
# 40           12             0.42   0.4  0.23
# 41           11             0.33  0.13  0.22
# 42           21             0.27  0.18   0.1
# 43           78             0.00  0.58   0.0
# 44           16             0.09  0.25  0.14
# 45           17             0.35  0.26  0.22
# 49           12             0.38  0.72   0.3
# 50           14             0.38  0.72   0.3
# 52           14             0.43  0.44  0.38
# 53           15             0.48  0.49  0.64
# 54           12             0.38  0.29  0.27
# 56           10             0.58  0.28  0.67
# 57           15             0.24  0.26  0.14
# 58           21             0.21  0.04  0.09
# 59           13             0.48   0.7  0.52
# 60           35             0.48   0.7  0.52
# 63           11             0.78  0.64  0.71
# 64           16             0.50  0.33  0.46
# 65           14             0.34  0.44  0.49
# 66           24             0.81  0.94  0.83
# 67           11             0.55  0.49  0.56
# 69           20             0.52  0.51  0.48
# 70           27             0.58  0.58   0.4
# 71           18             0.67  0.58  0.44
# 72           13             0.42   0.3  0.38
# 73           27             0.38  0.42  0.26
# 74           10             0.37  0.37  0.37
# 76           15             0.24  0.32  0.41
# 78           14             0.16  0.22  0.26
# 79           44             0.38  0.75  0.29
# 80           21             0.55  0.43  0.24
# 81           34             0.00  0.43  0.52
# 82           25             0.67   0.9  0.84
# 84           11             0.42  0.66   0.7
# 85           22             0.18   0.3  0.16
# 86           20             0.54   0.0   0.0
# 87           19             0.59  0.55  0.44
# 89           20             0.30  0.51  0.25
# 90           12             0.45  0.38  0.55

# %%
new_df.to_csv('../Resources/ML_player_dataset.csv', index=False)

# %%
#Closing the connection
conn.close()
