# %%
import csv

# %%
with open ("./Resources/Players_of_Interest.csv", 'r') as f:
    reader = csv.DictReader(f)
    
    for row in reader:
        print(row)
# Out:
# OrderedDict([('season', '2012'), ('name', 'Jack Hillen'), ('team', 'WSH'), ('position', 'D'), ('games_played', '23'), ('corsi_percentage', '0.49'), ('fenwick_percentage', '0.5'), ('goals', '3'), ('points', '9'), ('penalty_minutes', '14'), ('hits', '10'), ('takeaways', '2'), ('giveaways', '13'), ('games_missed', '0'), ('points_per_game', '0.39')])
# OrderedDict([('season', '2012'), ('name', 'David Perron'), ('team', 'STL'), ('position', 'L'), ('games_played', '48'), ('corsi_percentage', '0.58'), ('fenwick_percentage', '0.58'), ('goals', '10'), ('points', '25'), ('penalty_minutes', '44'), ('hits', '48'), ('takeaways', '26'), ('giveaways', '14'), ('games_missed', '0'), ('points_per_game', '0.52')])
# ...
